# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('more-Extracted-data.csv')

# %%
data = data.drop(columns = [data.columns[0]], axis=1)

# %%
data.to_csv('Extracted-data.csv', index=False)

# %%
data.head()
# Out:
#           disease                                        categories  \
# 0        Anaemia                            Iron Deficiency Anaemia
# 1         Anaemia                              Megaloblastic Anemia
# 2             Do   Aplastic Anaemia (Bone Marrow Failure) Aplastic
# 3             Do   Aplastic Anaemia (Bone Marrow Failure) Aplastic
# 4  Prophylactics   Aplastic Anaemia (Bone Marrow Failure) Aplastic
#
#                                Clinical presentation  \
# 0  fatigue, palpitation, dizziness, glossitis, ko...
# 1  Pallor, depression, hair loss, pins and needle...
# 2  Vary with severity but include;  , Anaemia, ea...
# 3  Vary with severity but include;  , Anaemia, ea...
# 4  Vary with severity but include;  , Anaemia, ea...
#
#                                        Investigation  \
# 0    , Full blood picture (FBP) , Peripheral smea...
# 1  FBC-Low Hb, sometime pancytopenia, raised mcv ...
# 2  FBP, peripheral smear, reticulocyte count,  , ...
# ...

# %%
data.disease.unique()
# Out:
# array(['Anaemia ', 'Anaemia', 'Do ', 'Prophylactics ', 'X 109/L. ',
#        ',Spontaneous ', ',Haemorrhage ', 'Factor ', 'Classification ',
#        'Reinitiate ', 'Adverse ', 'Cholera\nCholera ', 'After ',
#        'Public Health Control Measures ', 'A ', '°C ', 'Glucose ',
#        'Below ', 'Postnatal ', 'Viral Infections ', 'C ',
#        'Hypersecretion A Hyoscine ', 'Intradermal ',
#        'Asymptomatic Malaria Case Asymptomatic ',
#        'Symptomatic Malaria Case ', 'Children ', 'Normal ', 'Total ',
#        'Artesunate ', '\n*Half ', '\nKg Mg ', '\nIf ', '\nChildren ',
#        '\nPharmacological Treatment ',
#        'Recommended First -Line Regimens ', 'Estimated ', '121Table ',
#        'Monitoring Patients ', 'Clinical ',
#        'Immune Reconstitution Inflammatory Syndrome ',
#        'Antiretroviral Therapy ', 'Third-Line ', 'Nephrotoxicity ',
#        'Recommended ', 'Daily ', 'Proposed ', 'Special ',
#        'General Treatment ', 'Treatment ', '\nS ', '\nC ',
# ...

# %%
# Out:
#       disease                                        categories  \
# 5   X 109/L.   Aplastic Anaemia (Bone Marrow Failure) Aplastic
# 7   X 109/L.   Aplastic Anaemia (Bone Marrow Failure) Aplastic
# 8   X 109/L.   Aplastic Anaemia (Bone Marrow Failure) Aplastic
# 10  X 109/L.   Aplastic Anaemia (Bone Marrow Failure) Aplastic
#
#                                 Clinical presentation  \
# 5   Vary with severity but include;  , Anaemia, ea...
# 7   Vary with severity but include;  , Anaemia, ea...
# 8   Vary with severity but include;  , Anaemia, ea...
# 10  Vary with severity but include;  , Anaemia, ea...
#
#                                         Investigation  \
# 5   FBP, peripheral smear, reticulocyte count,  , ...
# 7   \n  similar to aplastic anaemia, plus analysis...
# 8   \n  similar to aplastic anaemia, plus analysis...
# 10  \n  similar to aplastic anaemia, plus analysis...
#
#    Non-Pharmacological Treatment  \
# 5                            NaN
# ...
